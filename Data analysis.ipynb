# %% [markdown]
# # DATA ANALYSIS OF CAPSTONE PROJECT
# ## By Kiran Kumar S

# %% [markdown]
# # PART ONE :  Fandago Discrepency (backend Reviews vs front shown Stars)

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fandango=pd.read_csv("fandango_scrape.csv")

# %%
fandango.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %%
fandango.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    504 non-null    object
#  1   STARS   504 non-null    float64
#  2   RATING  504 non-null    float64
#  3   VOTES   504 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.9+ KB

# %%
fandango.describe()
# Out:
#             STARS      RATING         VOTES
# count  504.000000  504.000000    504.000000
# mean     3.558532    3.375794   1147.863095
# std      1.563133    1.491223   3830.583136
# min      0.000000    0.000000      0.000000
# 25%      3.500000    3.100000      3.000000
# 50%      4.000000    3.800000     18.500000
# 75%      4.500000    4.300000    189.750000
# max      5.000000    5.000000  34846.000000

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.scatterplot(data=fandango,y="VOTES",x="RATING")

# %%
fandango.corr()
# Out:
#            STARS    RATING     VOTES
# STARS   1.000000  0.994696  0.164218
# RATING  0.994696  1.000000  0.163764
# VOTES   0.164218  0.163764  1.000000

# %%
title="FILM title name (year)"

# %%
abc=title.split('(')

# %%
abc
# Out:
# ['FILM title name ', 'year)']

# %%
abc[-1]
# Out:
# 'year)'

# %%
abc[-1].replace(')','')
# Out:
# 'year'

# %%
fandango["YEAR"]=fandango['FILM'].apply(lambda title: title.split('(')[-1].replace(")","")) # max follow functions in series case

# %%
fandango["YEAR"]
# Out:
# 0      2015
# 1      2015
# 2      2015
# 3      2015
# 4      2015
#        ...
# 499    2015
# 500    2015
# 501    2015
# 502    1964
# 503    2012
# Name: YEAR, Length: 504, dtype: object

# %%
#fandango["YEAR"]=fandango['FILM'].str.split('(')

# %%
#len(fandango["YEAR"][1:-1][1])

# %%
fandango
# Out:
#                                      FILM  STARS  RATING  VOTES  YEAR
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                   Jurassic World (2015)    4.5     4.5  34390  2015
# 2                  American Sniper (2015)    5.0     4.8  34085  2015
# 3                        Furious 7 (2015)    5.0     4.8  33538  2015
# 4                       Inside Out (2015)    4.5     4.5  15749  2015
# ..                                    ...    ...     ...    ...   ...
# 499                      Valiyavan (2015)    0.0     0.0      0  2015
# 500            WWE SummerSlam 2015 (2015)    0.0     0.0      0  2015
# 501       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0  2015
# 502  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0  1964
# 503                         Zarafa (2012)    0.0     0.0      0  2012
#
# [504 rows x 5 columns]

# %%
fandango["YEAR"].value_counts()
# Out:
# 2015    478
# 2014     23
# 1964      1
# 2016      1
# 2012      1
# Name: YEAR, dtype: int64

# %%
sns.countplot(data=fandango,x="YEAR")

# %%
fandango.nlargest(10,"VOTES")
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    YEAR
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2014
# 6  2015
# 7  2015
# 8  2015
# 9  2014

# %%
(fandango[fandango["VOTES"]==0])["VOTES"].count()
# Out:
# 69

# %%
fans_rev=fandango[fandango["VOTES"]>0]

# %%
fans_rev
# Out:
#                             FILM  STARS  RATING  VOTES  YEAR
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1          Jurassic World (2015)    4.5     4.5  34390  2015
# 2         American Sniper (2015)    5.0     4.8  34085  2015
# 3               Furious 7 (2015)    5.0     4.8  33538  2015
# 4              Inside Out (2015)    4.5     4.5  15749  2015
# ..                           ...    ...     ...    ...   ...
# 430       That Sugar Film (2015)    5.0     5.0      1  2015
# 431            The Intern (2015)    5.0     5.0      1  2015
# 432        The Park Bench (2015)    5.0     5.0      1  2015
# 433         The Wanted 18 (2015)    5.0     5.0      1  2015
# 434       Z For Zachariah (2015)    5.0     5.0      1  2015
#
# [435 rows x 5 columns]

# %%
sns.kdeplot(data=fans_rev,x="RATING",clip=[0,5],fill=True,label="True ratings")
sns.kdeplot(data=fans_rev,x="STARS",clip=[0,5],fill=True,label="STARS displayed")
plt.legend(loc=(1.05,0.4))

# %%
fans_rev['STARS_DIFF']=fans_rev['STARS']-fans_rev['RATING']
# Out:
# <ipython-input-25-d3d31b5e88ad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fans_rev['STARS_DIFF']=fans_rev['STARS']-fans_rev['RATING']

# %%
fans_rev
# Out:
#                             FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1          Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2         American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3               Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4              Inside Out (2015)    4.5     4.5  15749  2015         0.0
# ..                           ...    ...     ...    ...   ...         ...
# 430       That Sugar Film (2015)    5.0     5.0      1  2015         0.0
# 431            The Intern (2015)    5.0     5.0      1  2015         0.0
# 432        The Park Bench (2015)    5.0     5.0      1  2015         0.0
# 433         The Wanted 18 (2015)    5.0     5.0      1  2015         0.0
# 434       Z For Zachariah (2015)    5.0     5.0      1  2015         0.0
#
# [435 rows x 6 columns]

# %%
fans_rev['STARS_DIFF']=fans_rev['STARS_DIFF'].round(2)
# Out:
# <ipython-input-27-6fe128db7d18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fans_rev['STARS_DIFF']=fans_rev['STARS_DIFF'].round(2)

# %%
fans_rev['STARS_DIFF']
# Out:
# 0      0.1
# 1      0.0
# 2      0.2
# 3      0.2
# 4      0.0
#       ...
# 430    0.0
# 431    0.0
# 432    0.0
# 433    0.0
# 434    0.0
# Name: STARS_DIFF, Length: 435, dtype: float64

# %%
sns.countplot(data=fans_rev,x='STARS_DIFF',palette="magma")

# %%
fans_rev[fans_rev["STARS_DIFF"]==1]
# Out:
#                  FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 381  Turbo Kid (2015)    5.0     4.0      2  2015         1.0

# %% [markdown]
# # PART TWO : Comparision of Fandango with  other websites

# %%
all_sites=pd.read_csv("all_sites_scores.csv")

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count
# 0                271107
# 1                 65709
# 2                103660
# 3                  3136
# ...

# %%
all_sites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        146 non-null    object
#  1   RottenTomatoes              146 non-null    int64
#  2   RottenTomatoes_User         146 non-null    int64
#  3   Metacritic                  146 non-null    int64
#  4   Metacritic_User             146 non-null    float64
#  5   IMDB                        146 non-null    float64
#  6   Metacritic_user_vote_count  146 non-null    int64
#  7   IMDB_user_vote_count        146 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 9.2+ KB

# %%
all_sites.describe()
# Out:
#        RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  \
# count      146.000000           146.000000  146.000000       146.000000
# mean        60.849315            63.876712   58.808219         6.519178
# std         30.168799            20.024430   19.517389         1.510712
# min          5.000000            20.000000   13.000000         2.400000
# 25%         31.250000            50.000000   43.500000         5.700000
# 50%         63.500000            66.500000   59.000000         6.850000
# 75%         89.000000            81.000000   75.000000         7.500000
# max        100.000000            94.000000   94.000000         9.600000
#
#              IMDB  Metacritic_user_vote_count  IMDB_user_vote_count
# count  146.000000                  146.000000            146.000000
# mean     6.736986                  185.705479          42846.205479
# std      0.958736                  316.606515          67406.509171
# ...

# %%
sns.scatterplot(data=all_sites,x="RottenTomatoes",y="RottenTomatoes_User")
plt.xlim=(0,100)
plt.ylim=(0,100)

# %%
all_sites["R_T_diff"]=all_sites["RottenTomatoes"]-all_sites["RottenTomatoes_User"] #large diff =critics liked than user small diff = user liked it more then critrics

# %%
all_sites
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# ...

# %%
all_sites["R_T_diff"].apply(abs).mean()
# Out:
# 15.095890410958905

# %%
 sns.histplot(data=all_sites,x="R_T_diff",kde=True,bins=25)

# %%
 sns.histplot(data=all_sites,x=all_sites["R_T_diff"].apply(abs),kde=True,bins=25)

# %%
all_sites.nsmallest(5,'R_T_diff')
# Out:
#                           FILM  RottenTomatoes  RottenTomatoes_User  \
# 3       Do You Believe? (2015)              18                   84
# 85           Little Boy (2015)              20                   81
# 105    Hitman: Agent 47 (2015)               7                   49
# 134    The Longest Ride (2015)              31                   73
# 125  The Wedding Ringer (2015)              27                   66
#
#      Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 3            22              4.7   5.4                          31
# 85           30              5.9   7.4                          38
# 105          28              3.3   5.9                          67
# 134          33              4.8   7.2                          49
# 125          35              3.3   6.7                         126
#
#      IMDB_user_vote_count  R_T_diff
# 3                    3136       -66
# 85                   5927       -61
# 105                  4260       -42
# ...

# %%
all_sites.nsmallest(5,'R_T_diff')["FILM"]
# Out:
# 3         Do You Believe? (2015)
# 85             Little Boy (2015)
# 105      Hitman: Agent 47 (2015)
# 134      The Longest Ride (2015)
# 125    The Wedding Ringer (2015)
# Name: FILM, dtype: object

# %%
all_sites.nlargest(5,'R_T_diff')
# Out:
#                                  FILM  RottenTomatoes  RottenTomatoes_User  \
# 69                  Mr. Turner (2014)              98                   56
# 112                 It Follows (2015)              96                   65
# 115          While We're Young (2015)              83                   52
# 37               Welcome to Me (2015)              71                   47
# 40   I'll See You In My Dreams (2015)              94                   70
#
#      Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 69           94              6.6   6.9                          98
# 112          83              7.5   6.9                         551
# 115          76              6.7   6.4                          65
# 37           67              6.9   5.9                          33
# 40           75              6.9   6.9                          14
#
#      IMDB_user_vote_count  R_T_diff
# 69                  13296        42
# 112                 64656        31
# ...

# %%
all_sites.nlargest(5,'R_T_diff')["FILM"]
# Out:
# 69                    Mr. Turner (2014)
# 112                   It Follows (2015)
# 115            While We're Young (2015)
# 37                 Welcome to Me (2015)
# 40     I'll See You In My Dreams (2015)
# Name: FILM, dtype: object

# %%
plt.figure(figsize=(10,4),dpi=150)
sns.scatterplot(data=all_sites,x="Metacritic",y="Metacritic_User")
plt.xlim=(0,100)
plt.ylim=(0,100)

# %%
plt.figure(figsize=(10,4),dpi=150)
sns.scatterplot(data=all_sites,x="Metacritic_user_vote_count",y="IMDB_user_vote_count")
plt.xlim=(0,100)
plt.ylim=(0,100)

# %%
all_sites.nlargest(1,"Metacritic_user_vote_count")
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 88  Mad Max: Fury Road (2015)              97                   88
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 88          89              8.7   8.3                        2375
#
#     IMDB_user_vote_count  R_T_diff
# 88                292023         9

# %%
all_sites.nlargest(1,"IMDB_user_vote_count")
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 14  The Imitation Game (2014)              90                   92
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 14          73              8.2   8.1                         566
#
#     IMDB_user_vote_count  R_T_diff
# 14                334164        -2

# %% [markdown]
# # fandango vs all_sites
# ## Part Three : Final solution

# %%
df=pd.merge(fandango,all_sites,on="FILM",how="inner")

# %%
df
# Out:
#                                    FILM  STARS  RATING  VOTES  YEAR  \
# 0           Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                 Jurassic World (2015)    4.5     4.5  34390  2015
# 2                American Sniper (2015)    5.0     4.8  34085  2015
# 3                      Furious 7 (2015)    5.0     4.8  33538  2015
# 4                     Inside Out (2015)    4.5     4.5  15749  2015
# ..                                  ...    ...     ...    ...   ...
# 140  Kumiko, The Treasure Hunter (2015)    3.5     3.5     41  2015
# 141  The Diary of a Teenage Girl (2015)    4.0     3.6     38  2015
# 142            The Wrecking Crew (2015)    4.5     4.2     38  2015
# 143                    Tangerine (2015)    4.0     3.9     36  2015
# 144            Maps to the Stars (2015)    3.5     3.1     35  2015
#
#      RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# ...

# %%
df.describe().transpose()['max']
# Out:
# STARS                              5.0
# RATING                             4.8
# VOTES                          34846.0
# RottenTomatoes                   100.0
# RottenTomatoes_User               94.0
# Metacritic                        94.0
# Metacritic_User                    9.6
# IMDB                               8.6
# Metacritic_user_vote_count      2375.0
# IMDB_user_vote_count          334164.0
# R_T_diff                          42.0
# Name: max, dtype: float64

# %%
import numpy as np

df['RT_Norm']=np.round(df["RottenTomatoes"]/20,1)
df['RTU_Norm']=np.round(df["RottenTomatoes_User"]/20,1)
df['MT_Norm']=np.round(df["Metacritic"]/20,1)
df['MTU_Norm']=np.round(df["Metacritic_User"]/2,1)
df['IMDB_Norm']=np.round(df["IMDB"]/2,1)

# %%
df.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015              25
# 1        Jurassic World (2015)    4.5     4.5  34390  2015              71
# 2       American Sniper (2015)    5.0     4.8  34085  2015              72
# 3             Furious 7 (2015)    5.0     4.8  33538  2015              81
# 4            Inside Out (2015)    4.5     4.5  15749  2015              98
#
#    RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                   42          46              3.2   4.2
# 1                   81          59              7.0   7.3
# 2                   85          72              6.6   7.4
# 3                   84          67              6.8   7.4
# 4                   90          94              8.9   8.6
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  R_T_diff  RT_Norm  \
# 0                         778                179506       -17      1.2
# ...

# %%
df.columns
# Out:
# Index(['FILM', 'STARS', 'RATING', 'VOTES', 'YEAR', 'RottenTomatoes',
#        'RottenTomatoes_User', 'Metacritic', 'Metacritic_User', 'IMDB',
#        'Metacritic_user_vote_count', 'IMDB_user_vote_count', 'R_T_diff',
#        'RT_Norm', 'RTU_Norm', 'MT_Norm', 'MTU_Norm', 'IMDB_Norm'],
#       dtype='object')

# %%
Norm_strs=df[['RT_Norm', 'RTU_Norm', 'MT_Norm', 'MTU_Norm', 'IMDB_Norm','STARS', 'RATING']]

# %%
Norm_strs.head()
# Out:
#    RT_Norm  RTU_Norm  MT_Norm  MTU_Norm  IMDB_Norm  STARS  RATING
# 0      1.2       2.1      2.3       1.6        2.1    4.0     3.9
# 1      3.6       4.0      3.0       3.5        3.6    4.5     4.5
# 2      3.6       4.2      3.6       3.3        3.7    5.0     4.8
# 3      4.0       4.2      3.4       3.4        3.7    5.0     4.8
# 4      4.9       4.5      4.7       4.4        4.3    4.5     4.5

# %%
plt.figure(figsize=(15,6),dpi=200)
sns.kdeplot(data=Norm_strs,clip=[0,5],shade=True,palette="Set1")

# %%
plt.figure(figsize=(15,6),dpi=200)
sns.kdeplot(data=Norm_strs[["STARS","RT_Norm"]],clip=[0,5],shade=True,palette="Set1")

# %%
sns.histplot(data=Norm_strs,bins=50)

# %%
sns.clustermap(data=Norm_strs,cmap="magma",col_cluster=False)

# %%
Norm_strs.head()
# Out:
#    RT_Norm  RTU_Norm  MT_Norm  MTU_Norm  IMDB_Norm  STARS  RATING
# 0      1.2       2.1      2.3       1.6        2.1    4.0     3.9
# 1      3.6       4.0      3.0       3.5        3.6    4.5     4.5
# 2      3.6       4.2      3.6       3.3        3.7    5.0     4.8
# 3      4.0       4.2      3.4       3.4        3.7    5.0     4.8
# 4      4.9       4.5      4.7       4.4        4.3    4.5     4.5

# %%
Norm_strs['FILM']=df['FILM']
# Out:
# <ipython-input-62-d5807bbc262c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Norm_strs['FILM']=df['FILM']

# %%
Norm_strs
# Out:
#      RT_Norm  RTU_Norm  MT_Norm  MTU_Norm  IMDB_Norm  STARS  RATING  \
# 0        1.2       2.1      2.3       1.6        2.1    4.0     3.9
# 1        3.6       4.0      3.0       3.5        3.6    4.5     4.5
# 2        3.6       4.2      3.6       3.3        3.7    5.0     4.8
# 3        4.0       4.2      3.4       3.4        3.7    5.0     4.8
# 4        4.9       4.5      4.7       4.4        4.3    4.5     4.5
# ..       ...       ...      ...       ...        ...    ...     ...
# 140      4.4       3.2      3.4       3.2        3.4    3.5     3.5
# 141      4.8       4.0      4.4       3.2        3.5    4.0     3.6
# 142      4.6       4.2      3.4       3.5        3.9    4.5     4.2
# 143      4.8       4.3      4.3       3.6        3.7    4.0     3.9
# 144      3.0       2.3      3.4       2.9        3.2    3.5     3.1
#
#                                    FILM
# 0           Fifty Shades of Grey (2015)
# 1                 Jurassic World (2015)
# ...

# %%
Norm_strs.columns
# Out:
# Index(['RT_Norm', 'RTU_Norm', 'MT_Norm', 'MTU_Norm', 'IMDB_Norm', 'STARS',
#        'RATING', 'FILM'],
#       dtype='object')

# %%
Norm_Films=Norm_strs[['FILM','RT_Norm', 'RTU_Norm', 'MT_Norm', 'MTU_Norm', 'IMDB_Norm', 'STARS',
       'RATING']]

# %%
Norm_Films
# Out:
#                                    FILM  RT_Norm  RTU_Norm  MT_Norm  MTU_Norm  \
# 0           Fifty Shades of Grey (2015)      1.2       2.1      2.3       1.6
# 1                 Jurassic World (2015)      3.6       4.0      3.0       3.5
# 2                American Sniper (2015)      3.6       4.2      3.6       3.3
# 3                      Furious 7 (2015)      4.0       4.2      3.4       3.4
# 4                     Inside Out (2015)      4.9       4.5      4.7       4.4
# ..                                  ...      ...       ...      ...       ...
# 140  Kumiko, The Treasure Hunter (2015)      4.4       3.2      3.4       3.2
# 141  The Diary of a Teenage Girl (2015)      4.8       4.0      4.4       3.2
# 142            The Wrecking Crew (2015)      4.6       4.2      3.4       3.5
# 143                    Tangerine (2015)      4.8       4.3      4.3       3.6
# 144            Maps to the Stars (2015)      3.0       2.3      3.4       2.9
#
#      IMDB_Norm  STARS  RATING
# ...

# %%
Best_Films=Norm_Films.nlargest(10,'RT_Norm')['FILM']

# %%
Worst_films=Norm_Films.nsmallest(10,'RT_Norm')['FILM']

# %%
Wrst_Film=Norm_Films.nsmallest(10,'RT_Norm')

# %%
bst_film=Norm_Films.nlargest(10,'RT_Norm')

# %%
plt.figure(figsize=(15,6),dpi=200)
sns.kdeplot(data=Wrst_Film,clip=[0,5],shade=True,palette="Set1")

# %%
Wrst_Film
# Out:
#                              FILM  RT_Norm  RTU_Norm  MT_Norm  MTU_Norm  \
# 49  Paul Blart: Mall Cop 2 (2015)      0.2       1.8      0.6       1.2
# 25                 Taken 3 (2015)      0.4       2.3      1.3       2.3
# 28          Fantastic Four (2015)      0.4       1.0      1.4       1.2
# 54             Hot Pursuit (2015)      0.4       1.8      1.6       1.8
# 84        Hitman: Agent 47 (2015)      0.4       2.4      1.4       1.6
# 50       The Boy Next Door (2015)      0.5       1.8      1.5       2.8
# 77             Seventh Son (2015)      0.6       1.8      1.5       2.0
# 78               Mortdecai (2015)      0.6       1.5      1.4       1.6
# 83              Sinister 2 (2015)      0.6       1.7      1.6       2.5
# 87     Unfinished Business (2015)      0.6       1.4      1.6       1.9
#
#     IMDB_Norm  STARS  RATING
# 49        2.2    3.5     3.5
# 25        3.0    4.5     4.1
# 28        2.0    3.0     2.7
# 54        2.4    4.0     3.7
# ...

# %%
df1=Wrst_Film.loc[25]

# %%
df1
# Out:
# FILM         Taken 3 (2015)
# RT_Norm                 0.4
# RTU_Norm                2.3
# MT_Norm                 1.3
# MTU_Norm                2.3
# IMDB_Norm                 3
# STARS                   4.5
# RATING                  4.1
# Name: 25, dtype: object

# %%
0.4+2.3+1.3+2.3+3
# Out:
# 9.3

# %%
9.3/5
# Out:
# 1.86

# %% [markdown]
# #### Clearly, we can see that fandangos ratings are higher than the all other sites rating and we can also see for worst movies also fandango is giving the top ratings .For example Takken 3 average of all_sites ratings is 1.86 but fandango rating is 4.5
